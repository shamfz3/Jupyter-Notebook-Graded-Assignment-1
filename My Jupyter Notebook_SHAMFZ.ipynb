# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Shamfas Abdulla__
#
# Data Engineer

# %% [markdown]
# >*I am interested in Data Science because, I believe data science is the future.*
#
# >*Data Science can help us improve our business to next level.*

# %% [markdown]
# ### My code will do complex mathematics calculations

# %%
(1+1)-(2*2)+(3/3)+5+(4*20)
# Out:
# 84.0

# %% [markdown]
# ***

# %% [markdown]
# - BODMAS

# %% [markdown]
# ![bodmas.png](attachment:8af8a067-210d-4442-af08-7c760a92860c.png)

# %% [markdown]
# What is BODMAS (https://thirdspacelearning.com/blog/what-is-bodmas/)

# %% [markdown]
# |#|Letters| Acronym|
# |--|---| --------|
# |1| B | Brackets |
# |2| O | Orders |
# |3| D | Division |
# |4| M | Multiplication |
# |5| A | Addition |
# |6| S | Subtraction |

# %% [markdown]
# ***
